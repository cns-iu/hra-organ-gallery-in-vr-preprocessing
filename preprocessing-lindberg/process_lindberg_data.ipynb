# %% [markdown]
# ## A notebook to preprocess STORM data

# %%
# install and import libraries
# %pip install pandas

import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# load data
df = pd.read_csv(
    "data/Probe1_ORF1p-647sl_data_export_100nm_10pt.csv")

df
# Out:
#        image-ID  cycle  z-step  frame  accum  photon-count  photon-count11  \
# 0           454      0       2     54      1       1982.39         448.952
# 1           518      0       2    118      1       1807.05         398.383
# 2           589      0       2    189      1       1831.32         416.867
# 3           590      0       2    190      1       1849.01         397.793
# 4           600      0       3      0      1       2333.30         560.687
# ...         ...    ...     ...    ...    ...           ...             ...
# 31222     29198      0     145    198      1       1255.83         788.455
# 31223     29199      0     145    199      1       1254.38         799.747
# 31224     29211      0     146     11      1       1412.31         823.388
# 31225     29215      0     146     15      1       1028.53         588.489
# 31226     29219      0     146     19      1       1368.53         783.234
#
# ...

# %%
# keep only relevant columns
df_filtered = df[['x', 'y', 'z']]

df_filtered.loc[:,"Cell Type"] = "No Cell Type"
df_filtered
# Out:
# C:\Users\abueckle\AppData\Local\Temp\1\ipykernel_9056\978096714.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.loc[:,"Cell Type"] = "No Cell Type"
#              x         y          z     Cell Type
# 0      30014.0  13923.00    853.534  No Cell Type
# 1      36725.9  14086.20    851.323  No Cell Type
# 2      26357.8   3755.73    871.586  No Cell Type
# 3      26337.2   3759.83    854.928  No Cell Type
# 4      33869.3  20214.50    865.554  No Cell Type
# ...        ...       ...        ...           ...
# 31222  30637.3  33685.60  14337.000  No Cell Type
# 31223  30641.5  33712.60  14377.800  No Cell Type
# 31224  30679.8  33697.60  14383.600  No Cell Type
# 31225  30629.7  33647.40  14432.600  No Cell Type
# ...

# %%
# export
df_filtered.to_csv(
    "output/Probe1_ORF1p-647sl_data_export_100nm_10pt_processed.csv", index=False)
